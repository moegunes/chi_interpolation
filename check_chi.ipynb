# %%
# %load_ext autoreload
# %autoreload 2
from input import q,r
import numpy as np
import matplotlib.pyplot as plt
from utils.io import load_dict
from visualization.pp import plot_chi, plot_parameters

import scienceplots
plt.style.use(['science'])
plt.rcParams['figure.dpi'] = 300

parameters=load_dict('parameters')
#parameters2=load_dict('parameters_best')

# %% [markdown]
# # $r_s = 2$

# %%
plot_chi(r, q,parameters,rs=1,error=0)
# Out:
# ∫chi(r)r^2dr: 0.000002
# /Users/muhammedxgunes/Desktop/research/chi_interpolation/src/visualization/pp.py:159: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.subplots_adjust(hspace=0.35, left=0.15, right=0.95, top=0.92, bottom=0.12)

# %%
plot_chi(r, q,parameters,rs=1,error=1)
# Out:
# ∫chi(r)r^2dr: 0.000002

# %% [markdown]
# # $r_s = 10$

# %%
plot_chi(r, q,parameters,rs=10,error=0)
# Out:
# ∫chi(r)r^2dr: -0.000002

# %%
plot_chi(r, q,parameters,rs=10,error=1)
# Out:
# ∫chi(r)r^2dr: -0.000002

# %%
plot_chi(r, q,parameters,rs=10,error=1)
# Out:
# ∫chi(r)r^2dr: 0.000013

# %% [markdown]
# # Parameters as a function of $r_s$

# %%
rslist=np.arange(0.25, 10.25, 0.25)

rslist[7]
# Out:
# np.float64(2.0)

# %%
plot_parameters(parameters)
# Out:
# /Users/muhammedxgunes/Desktop/research/chi_interpolation/src/visualization/pp.py:65: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.supxlabel(r"$r_s$", fontsize=font_size, y=0.04)

# %%
phi=2.5
np.minimum(phi, 2 * np.pi - phi)
# Out:
# np.float64(2.5)
